# %% [markdown]
# # TP1 - Prise en main de Python, Matplotlib et Pandas
#
# Bienvenue dans ce premier TP.
#
# L'objectif est de vous faire manipuler progressivement :
#
# - les bases de **Python** ;
# - les premiers graphiques avec **Matplotlib** ;
# - les tableaux de données avec **Pandas**.
#
# Ce notebook est **guidé** : lisez les consignes, exécutez les cellules dans l'ordre, puis complétez les parties marquées **TODO** ou **À vous de jouer**.

# %% [markdown]
# ## Consignes de travail
#
# - Exécutez les cellules **de haut en bas**.
# - Complétez les cellules de code sans tout réécrire inutilement.
# - Quand une question demande un commentaire, rédigez une réponse **courte mais claire**.
# - Testez vos idées : dans un notebook, vous avez le droit d'essayer, de vous tromper, puis de corriger.
#
# Le fichier de données utilisé dans ce TP est : **`etudiants_tp1.csv`**.

# %% [markdown]
# ## Plan du TP
#
# 1. Revoir les bases de Python
# 2. Faire quelques traitements simples en Python
# 3. Tracer de premiers graphiques avec Matplotlib
# 4. Charger un fichier CSV avec Pandas
# 5. Comprendre la structure d'un dataset
# 6. Faire des manipulations de base avec Pandas
# 7. Produire une première visualisation avec Pandas
# 8. Répondre à des questions de synthèse

# %% [markdown]
# ---
# ## Partie 1 - Prise en main de Python
#
# Dans cette partie, vous allez revoir les éléments indispensables pour la suite : variables, types, listes, dictionnaires, conditions et boucles.

# %%
# Exercice 1 - Variables simples
# À vous de jouer : complétez les variables ci-dessous.

prenom = ""
age = 0
ville = ""

# TODO : affichez une phrase de présentation du type :
# Bonjour, je m'appelle ..., j'ai ... ans et j'habite à ...

# %%
# Exercice 2 - Types de base

entier = 12
reel = 3.5
texte = "Python"

# TODO : affichez le type de chaque variable avec la fonction type()
# Exemple attendu : <class 'int'>, <class 'float'>, <class 'str'>

# %%
# Exercice 3 - Listes

notes = [12, 15, 9, 14, 11]

# TODO 1 : affichez le premier élément de la liste
# TODO 2 : affichez le dernier élément de la liste
# TODO 3 : ajoutez la note 16 à la fin de la liste
# TODO 4 : affichez ensuite la liste complète

# %%
# Exercice 4 - Dictionnaires

etudiant = {
    "nom": "Lina",
    "age": 19,
    "specialite": "Informatique"
}

# TODO 1 : affichez la valeur associée à la clé "nom"
# TODO 2 : ajoutez une nouvelle clé "ville" avec la valeur "Kourou"
# TODO 3 : affichez le dictionnaire complet

# %%
# Exercice 5 - Condition simple

note = 11

# TODO : écrivez une condition qui affiche :
# - "Admis" si la note est supérieure ou égale à 10
# - "Ajourné" sinon

# %%
# Exercice 6 - Boucle simple

nombres = [3, 6, 9, 12, 15]

# TODO : parcourez la liste avec une boucle for
# puis affichez chaque nombre

# %% [markdown]
# ### Petit rappel
#
# - Une **variable** stocke une valeur.
# - Une **liste** permet de stocker plusieurs éléments ordonnés.
# - Un **dictionnaire** associe des clés à des valeurs.
# - Une **condition** permet de choisir entre plusieurs cas.
# - Une **boucle** permet de répéter une action.

# %% [markdown]
# ---
# ## Partie 2 - Premiers traitements simples en Python
#
# Ici, l'objectif est d'utiliser Python sur de petites données sans utiliser encore Pandas.

# %%
# Données pour les exercices de cette partie
notes_classe = [12, 8, 15, 9, 14, 16, 11, 10, 7, 13]

# %%
# Exercice 7 - Parcourir une liste

# TODO : affichez chaque note de la liste notes_classe avec une boucle for

# %%
# Exercice 8 - Filtrer des valeurs

# TODO : affichez uniquement les notes strictement supérieures à 12

# %%
# Exercice 9 - Calculer une moyenne

# TODO : calculez la moyenne de notes_classe
# Indication : vous pouvez utiliser sum(...) et len(...)

# %%
# Exercice 10 - Compter des occurrences

reponses = ["oui", "non", "oui", "oui", "non", "oui", "non"]

# TODO : comptez combien de fois la valeur "oui" apparaît dans la liste

# %% [markdown]
# ### Ce qu'il faut retenir
#
# Ces exercices montrent déjà des opérations très fréquentes en analyse de données :
#
# - parcourir une collection ;
# - sélectionner certaines valeurs ;
# - calculer un indicateur simple ;
# - compter des cas particuliers.

# %% [markdown]
# ---
# ## Partie 3 - Introduction à Matplotlib
#
# **Matplotlib** est une bibliothèque Python qui permet de créer des graphiques.
#
# Dans cette partie, vous allez produire vos premiers visuels à partir de listes Python.

# %%
# Import de la bibliothèque de visualisation
import matplotlib.pyplot as plt

# %%
# Exercice 11 - Tracer une courbe

seances = [1, 2, 3, 4, 5, 6]
moyennes = [9, 10, 11, 12, 12, 13]

# TODO : tracez une courbe avec plt.plot(...)
# TODO : ajoutez un titre
# TODO : ajoutez un label sur l'axe x
# TODO : ajoutez un label sur l'axe y
# TODO : affichez le graphique avec plt.show()

# %%
# Exercice 12 - Tracer un histogramme

notes_graphique = [12, 8, 15, 9, 14, 16, 11, 10, 7, 13, 12, 12, 15]

# TODO : créez un histogramme des notes
# TODO : ajoutez un titre et les labels des axes
# TODO : affichez le graphique

# %% [markdown]
# ### Interprétation
#
# Dans la cellule Markdown ci-dessous, rédigez en **2 ou 3 phrases** ce que montre l'un de vos graphiques.

# %% [markdown]
# **Votre commentaire ici :**
#
# _Remplacez ce texte par votre interprétation._

# %% [markdown]
# ---
# ## Partie 4 - Introduction à Pandas
#
# **Pandas** est une bibliothèque très utilisée pour manipuler des tableaux de données.
#
# Un objet central de Pandas est le **DataFrame**, c'est-à-dire un tableau avec des lignes et des colonnes, un peu comme une feuille de calcul.

# %%
import pandas as pd

# %%
# Chargement du fichier CSV
# Le fichier etudiants_tp1.csv doit être dans le même dossier que ce notebook.
# Si besoin, on essaie aussi le chemin depuis la racine du dépôt.

from pathlib import Path

csv_path = Path("etudiants_tp1.csv")
if not csv_path.exists():
    csv_path = Path("TP/TP1/etudiants_tp1.csv")

df = pd.read_csv(csv_path)

# TODO : affichez les 5 premières lignes du dataset

# %%
# Exercice 13 - Premières observations

# TODO 1 : affichez les 5 dernières lignes avec la bonne méthode Pandas
# TODO 2 : affichez la taille du dataset (nombre de lignes, nombre de colonnes)
# TODO 3 : affichez la liste des colonnes

# %% [markdown]
# ### Observation
#
# Prenez le temps de lire les noms de colonnes avant d'aller plus loin. Comprendre le sens des colonnes est une étape essentielle en analyse de données.

# %% [markdown]
# ---
# ## Partie 5 - Comprendre un dataset
#
# Avant de faire des calculs, il faut toujours comprendre la structure du tableau :
#
# - quels sont les types de colonnes ;
# - quelles colonnes sont numériques ;
# - quelles colonnes sont catégorielles ;
# - s'il existe des valeurs manquantes.

# %%
# Exercice 14 - Informations générales sur le DataFrame

# TODO : utilisez la méthode adaptée pour afficher les informations générales sur le dataset
# Indice : regardez le nom, le type des colonnes et le nombre de valeurs non nulles

# %%
# Exercice 15 - Types de colonnes

# TODO : affichez le type de chaque colonne

# %%
# Exercice 16 - Valeurs manquantes

# TODO : calculez le nombre de valeurs manquantes par colonne

# %% [markdown]
# ### Réflexion
#
# Dans les cellules Markdown suivantes, répondez brièvement.

# %% [markdown]
# **Question 1** : Quelles colonnes vous semblent **numériques** ?
#
# _Votre réponse ici._

# %% [markdown]
# **Question 2** : Quelles colonnes vous semblent **catégorielles** ?
#
# _Votre réponse ici._

# %% [markdown]
# **Question 3** : Quelle colonne pourrait servir de **target** si l'on voulait prédire un résultat ?
#
# _Votre réponse ici._

# %% [markdown]
# ---
# ## Partie 6 - Manipulations de base avec Pandas
#
# Dans cette partie, vous allez interroger le tableau pour sélectionner des colonnes, filtrer des lignes et calculer quelques statistiques simples.

# %%
# Exercice 17 - Sélectionner une colonne

# TODO : sélectionnez uniquement la colonne note_python

# %%
# Exercice 18 - Sélectionner plusieurs colonnes

# TODO : sélectionnez les colonnes age, specialite et note_python

# %%
# Exercice 19 - Filtrer des lignes

# TODO : affichez uniquement les étudiants ayant une note_python >= 12

# %%
# Exercice 20 - Filtrer avec plusieurs conditions

# TODO : affichez les étudiants ayant :
# - note_python >= 12
# - et absences <= 3

# %%
# Exercice 21 - Statistiques simples

# TODO 1 : calculez la moyenne de la colonne note_python
# TODO 2 : calculez le minimum de la colonne absences
# TODO 3 : calculez le maximum de la colonne absences

# %%
# Exercice 22 - Compter des catégories

# TODO : comptez les occurrences de chaque spécialité

# %% [markdown]
# ### Point méthode
#
# Quand vous manipulez un DataFrame, posez-vous toujours ces questions :
#
# - Sur **quelle colonne** je travaille ?
# - Est-ce que je veux **toutes les lignes** ou seulement certaines ?
# - Est-ce que je cherche une **valeur**, un **compte**, ou une **statistique** ?

# %% [markdown]
# ---
# ## Partie 7 - Première visualisation avec Pandas
#
# Pandas permet de produire rapidement des graphiques, souvent en s'appuyant sur Matplotlib.

# %%
# Exercice 23 - Visualiser une distribution numérique

# TODO : produisez un histogramme de la colonne note_python
# TODO : ajoutez un titre et les labels des axes
# TODO : affichez le graphique

# %%
# Exercice 24 - Visualiser une variable catégorielle

# TODO : produisez un graphique simple montrant le nombre d'étudiants par spécialité
# Indice : vous pouvez commencer par value_counts()

# %% [markdown]
# **Commentaire d'observation**
#
# Décrivez rapidement une information intéressante visible sur vos graphiques.

# %% [markdown]
# _Votre commentaire ici._

# %% [markdown]
# ---
# ## Partie 8 - Questions de synthèse
#
# Répondez dans les cellules texte suivantes. L'objectif n'est pas d'écrire beaucoup, mais de montrer que vous avez compris la structure du dataset.

# %% [markdown]
# **1. Combien y a-t-il de lignes et de colonnes dans le dataset ?**
#
# _Votre réponse ici._

# %% [markdown]
# **2. Quelles sont les variables principales du dataset ?**
#
# _Votre réponse ici._

# %% [markdown]
# **3. Quelles variables sont numériques ?**
#
# _Votre réponse ici._

# %% [markdown]
# **4. Quelles variables sont catégorielles ?**
#
# _Votre réponse ici._

# %% [markdown]
# **5. Y a-t-il des valeurs manquantes ? Si oui, dans quelles colonnes ?**
#
# _Votre réponse ici._

# %% [markdown]
# **6. Quelle variable pourrait être prédite comme target ?**
#
# _Votre réponse ici._

# %% [markdown]
# **7. Donnez une observation intéressante sur les données.**
#
# _Votre réponse ici._

# %% [markdown]
# ## Fin du TP
#
# Si vous avez terminé :
#
# - relisez vos réponses ;
# - vérifiez que toutes les cellules importantes ont bien été exécutées ;
# - assurez-vous que vos commentaires sont rédigés en français clair.
#
# L'objectif de ce TP n'est pas d'aller vite, mais de devenir à l'aise avec l'environnement notebook et les premières manipulations de données.
