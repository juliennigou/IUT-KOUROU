# %% [markdown]
# # TP2 - Exploration de données avec Pandas et Matplotlib
#
# Dans ce TP, vous allez explorer **deux datasets réels**, mais **pas en même temps**.
#
# Nous allons suivre l'ordre suivant :
#
# 1. explorer complètement le dataset **Titanic** ;
# 2. explorer ensuite le dataset **House Prices**.
#
# L'objectif est de vous entraîner à :
#
# - lire un dataset ;
# - comprendre les colonnes ;
# - identifier une **target** ;
# - distinguer les **features** numériques et catégorielles ;
# - détecter les valeurs manquantes ;
# - tracer plusieurs graphiques utiles ;
# - observer les phénomènes de **déséquilibre** ;
# - proposer un premier tri de variables avant le machine learning.

# %% [markdown]
# ## Consignes de travail
#
# - Exécutez les cellules **dans l'ordre**.
# - Complétez les cellules de code sans tout réécrire inutilement.
# - Quand une question demande un commentaire, rédigez une **réponse courte et claire en français**.
# - Prenez le temps de **lire les sorties** et de **regarder les graphiques**.
# - Le but du TP est de **comprendre les données**, pas encore d'entraîner un modèle.

# %% [markdown]
# ## Plan du TP
#
# 1. Charger les datasets
# 2. Partie A : exploration complète de `Titanic`
# 3. Partie B : exploration complète de `House Prices`
# 4. Synthèse finale : features, target, difficultés, déséquilibres

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (8, 4)

# %%
# Chargement des fichiers CSV
# Le notebook peut être exécuté depuis la racine du dépôt ou depuis TP/TP2.

from pathlib import Path

titanic_path = Path("TP/TP2/titanic-dataset.csv")
house_path = Path("TP/TP2/house_prices.csv")

if not titanic_path.exists():
    titanic_path = Path("titanic-dataset.csv")

if not house_path.exists():
    house_path = Path("house_prices.csv")

df_titanic = pd.read_csv(titanic_path)
df_house = pd.read_csv(house_path)

print("Titanic :", df_titanic.shape)
print("House Prices :", df_house.shape)

# %% [markdown]
# ---
# ## Partie A - Exploration complète du dataset Titanic
#
# Dans cette première grande partie, vous allez explorer **uniquement** le dataset Titanic.
#
# On veut comprendre :
#
# - ce que représentent les colonnes ;
# - quelle est la target ;
# - si les classes sont équilibrées ou non ;
# - quelles variables semblent utiles pour prédire la survie.

# %% [markdown]
# ### A1 - Aperçu du dataset Titanic

# %%
# Exercice 1 - Premières observations sur Titanic
# TODO 1 : affichez les 5 premières lignes de df_titanic
# TODO 2 : affichez les 5 dernières lignes de df_titanic
# TODO 3 : affichez le nombre de lignes et de colonnes
# TODO 4 : affichez la liste des colonnes

# %%
# Exercice 2 - Informations générales sur Titanic
# TODO 1 : affichez les informations générales du DataFrame avec la méthode adaptée
# TODO 2 : affichez le type de chaque colonne

# %% [markdown]
# **Question 1** : Quel problème pourrait-on chercher à résoudre avec ce dataset ?
#
# _Votre réponse ici._

# %% [markdown]
# **Question 2** : Quelle colonne semble être la **target** dans Titanic ?
#
# _Votre réponse ici._

# %% [markdown]
# ### A2 - Types de variables
#
# Il faut maintenant distinguer les variables numériques, catégorielles et textuelles.

# %%
# Exercice 3 - Colonnes numériques et non numériques
# TODO 1 : créez une liste nommée titanic_numeriques
# contenant les colonnes numériques de df_titanic

# TODO 2 : créez une liste nommée titanic_non_numeriques
# contenant les colonnes non numériques de df_titanic

# TODO 3 : affichez les deux listes

# %% [markdown]
# **Question 3** : Quelles colonnes vous semblent plutôt être du texte ou des identifiants, donc peu utiles directement comme features ?
#
# _Votre réponse ici._

# %% [markdown]
# ### A3 - Valeurs manquantes
#
# Avant toute analyse sérieuse, il faut repérer les données incomplètes.

# %%
# Exercice 4 - Nombre de valeurs manquantes dans Titanic
# TODO 1 : calculez le nombre de valeurs manquantes par colonne
# TODO 2 : triez le résultat du plus grand au plus petit
# TODO 3 : stockez le résultat dans une variable si besoin

# %%
# Exercice 5 - Pourcentage de valeurs manquantes dans Titanic
# TODO 1 : calculez le pourcentage de NaN par colonne
# TODO 2 : triez le résultat du plus grand au plus petit
# TODO 3 : affichez le résultat

# %%
# Exercice 6 - Graphique des valeurs manquantes
# TODO 1 : tracez un diagramme en barres du nombre de valeurs manquantes par colonne
# TODO 2 : ajoutez un titre
# TODO 3 : ajoutez les labels des axes
# TODO 4 : affichez le graphique

# %% [markdown]
# **Question 4** : Quelles colonnes sont les plus problématiques et que pourrait-on faire avec elles ?
#
# _Votre réponse ici._

# %% [markdown]
# ### A4 - Analyse de la target : équilibre ou déséquilibre ?
#
# La target du Titanic est binaire. Il faut vérifier si les deux classes sont équilibrées.

# %%
# Exercice 7 - Distribution de la target Survived
# TODO 1 : comptez les occurrences de la colonne Survived
# TODO 2 : calculez aussi les proportions en pourcentage
# TODO 3 : affichez les deux résultats

# %%
# Exercice 8 - Graphique de la target
# TODO 1 : tracez un diagramme en barres de la colonne Survived
# TODO 2 : ajoutez un titre
# TODO 3 : ajoutez les labels des axes
# TODO 4 : affichez le graphique

# %% [markdown]
# **Question 5** : Le dataset Titanic est-il équilibré du point de vue de la target ? Justifiez avec les chiffres observés.
#
# _Votre réponse ici._

# %% [markdown]
# ### A5 - Analyse des variables numériques
#
# Nous allons observer les colonnes numériques importantes comme `Age`, `Fare`, `SibSp` et `Parch`.

# %%
# Exercice 9 - Statistiques numériques de Titanic
# TODO 1 : affichez les statistiques descriptives des colonnes numériques
# TODO 2 : calculez la moyenne, le minimum et le maximum de Age
# TODO 3 : calculez la moyenne, le minimum et le maximum de Fare

# %%
# Exercice 10 - Histogrammes sur Titanic
# TODO 1 : tracez un histogramme de Age
# TODO 2 : ajoutez un titre et les labels
# TODO 3 : affichez le graphique

# TODO 4 : tracez un histogramme de Fare
# TODO 5 : ajoutez un titre et les labels
# TODO 6 : affichez le graphique

# %%
# Exercice 11 - Boxplots sur Titanic
# TODO 1 : tracez un boxplot pour Age
# TODO 2 : tracez un boxplot pour Fare
# TODO 3 : commentez la présence éventuelle de valeurs extrêmes

# %% [markdown]
# **Question 6** : Que montrent les histogrammes et les boxplots sur la distribution des âges et des tarifs ?
#
# _Votre réponse ici._

# %% [markdown]
# ### A6 - Analyse des variables catégorielles
#
# Nous allons maintenant observer les grandes catégories du dataset.

# %%
# Exercice 12 - Fréquences des variables catégorielles
# TODO 1 : comptez les occurrences de Sex
# TODO 2 : comptez les occurrences de Pclass
# TODO 3 : comptez les occurrences de Embarked

# %%
# Exercice 13 - Graphiques des variables catégorielles
# TODO 1 : tracez un diagramme en barres pour Sex
# TODO 2 : tracez un diagramme en barres pour Pclass
# TODO 3 : tracez un diagramme en barres pour Embarked
# TODO 4 : ajoutez à chaque fois un titre et les labels

# %% [markdown]
# **Question 7** : Quelles catégories sont dominantes dans Titanic ? Voyez-vous déjà des déséquilibres intéressants ?
#
# _Votre réponse ici._

# %% [markdown]
# ### A7 - Relations entre les variables et la target
#
# C'est une étape importante : on cherche quelles variables semblent liées à la survie.

# %%
# Exercice 14 - Taux moyen de survie par groupe
# TODO 1 : calculez le taux moyen de survie par sexe
# TODO 2 : calculez le taux moyen de survie par classe (Pclass)
# TODO 3 : calculez le taux moyen de survie par port d'embarquement (Embarked)

# %%
# Exercice 15 - Graphiques des taux de survie
# TODO 1 : tracez un diagramme en barres du taux de survie par sexe
# TODO 2 : tracez un diagramme en barres du taux de survie par classe
# TODO 3 : tracez un diagramme en barres du taux de survie par port d'embarquement
# TODO 4 : ajoutez des titres et labels clairs

# %%
# Exercice 16 - Comparer une variable numérique à la target
# TODO 1 : calculez l'âge moyen selon Survived
# TODO 2 : calculez le tarif moyen selon Survived
# TODO 3 : si vous le souhaitez, tracez un boxplot de Fare en fonction de Survived

# %% [markdown]
# **Question 8** : Quelles variables vous paraissent les plus utiles pour prédire `Survived` ? Justifiez avec vos observations.
#
# _Votre réponse ici._

# %% [markdown]
# **Commentaire Titanic** : Rédigez 4 ou 5 phrases de synthèse sur ce que vous avez compris du dataset Titanic.
#
# _Votre commentaire ici._

# %% [markdown]
# ---
# ## Partie B - Exploration complète du dataset House Prices
#
# Nous passons maintenant au deuxième dataset.
#
# Cette fois, la logique est différente : la target attendue est **numérique**, donc on se rapproche d'un problème de **régression**.

# %% [markdown]
# ### B1 - Aperçu du dataset House Prices

# %%
# Exercice 17 - Premières observations sur House Prices
# TODO 1 : affichez les 5 premières lignes de df_house
# TODO 2 : affichez les 5 dernières lignes de df_house
# TODO 3 : affichez le nombre de lignes et de colonnes
# TODO 4 : affichez la liste des colonnes

# %%
# Exercice 18 - Informations générales sur House Prices
# TODO 1 : affichez les informations générales du DataFrame
# TODO 2 : affichez le type de chaque colonne

# %% [markdown]
# **Question 9** : Quel problème pourrait-on chercher à résoudre avec ce dataset ?
#
# _Votre réponse ici._

# %% [markdown]
# **Question 10** : Quelle colonne pourrait servir de **target** dans House Prices ?
#
# _Votre réponse ici._

# %% [markdown]
# ### B2 - Types de variables et colonnes peu utiles

# %%
# Exercice 19 - Colonnes numériques et non numériques dans House Prices
# TODO 1 : créez une liste nommée house_numeriques
# TODO 2 : créez une liste nommée house_non_numeriques
# TODO 3 : affichez les deux listes

# %% [markdown]
# **Question 11** : Quelles colonnes semblent plutôt textuelles, descriptives ou difficiles à utiliser directement comme features ?
#
# _Votre réponse ici._

# %% [markdown]
# ### B3 - Valeurs manquantes
#
# Ce dataset contient beaucoup plus de lignes, mais aussi davantage de colonnes incomplètes.

# %%
# Exercice 20 - Nombre de valeurs manquantes dans House Prices
# TODO 1 : calculez le nombre de NaN par colonne
# TODO 2 : triez le résultat du plus grand au plus petit

# %%
# Exercice 21 - Pourcentage de valeurs manquantes dans House Prices
# TODO 1 : calculez le pourcentage de NaN par colonne
# TODO 2 : triez le résultat du plus grand au plus petit
# TODO 3 : affichez le résultat

# %%
# Exercice 22 - Graphique des colonnes les plus incomplètes
# TODO 1 : sélectionnez par exemple les 10 colonnes avec le plus de NaN
# TODO 2 : tracez un diagramme en barres
# TODO 3 : ajoutez un titre et les labels
# TODO 4 : affichez le graphique

# %% [markdown]
# **Question 12** : Quelles colonnes semblent très difficiles à exploiter à cause des valeurs manquantes ?
#
# _Votre réponse ici._

# %% [markdown]
# ### B4 - Analyse de la target numérique
#
# Ici, la target n'est pas une classe, mais une valeur continue. Il faut regarder sa distribution et ses valeurs extrêmes.

# %%
# Exercice 23 - Statistiques sur Price (in rupees)
# TODO 1 : affichez les statistiques descriptives de la colonne Price (in rupees)
# TODO 2 : calculez la moyenne, le minimum et le maximum
# TODO 3 : calculez le nombre de valeurs manquantes de cette colonne

# %%
# Exercice 24 - Histogramme de la target
# TODO 1 : tracez un histogramme de Price (in rupees)
# TODO 2 : ajoutez un titre et les labels
# TODO 3 : affichez le graphique

# %%
# Exercice 25 - Boxplot de la target
# TODO 1 : tracez un boxplot de Price (in rupees)
# TODO 2 : observez si la distribution semble symétrique ou non
# TODO 3 : repérez la présence éventuelle de valeurs extrêmes

# %% [markdown]
# **Question 13** : La distribution du prix vous semble-t-elle équilibrée, étalée, concentrée ou très asymétrique ?
#
# _Votre réponse ici._

# %% [markdown]
# ### B5 - Analyse des variables catégorielles
#
# Certaines catégories sont peut-être très dominantes. Il faut le vérifier.

# %%
# Exercice 26 - Fréquences de quelques colonnes catégorielles
# TODO 1 : comptez les occurrences de location
# TODO 2 : comptez les occurrences de Status
# TODO 3 : comptez les occurrences de Transaction
# TODO 4 : comptez les occurrences de Furnishing

# %%
# Exercice 27 - Graphiques de catégories
# TODO 1 : affichez les 10 locations les plus fréquentes
# TODO 2 : tracez un diagramme en barres pour ces 10 locations
# TODO 3 : tracez un diagramme en barres pour Furnishing ou Transaction
# TODO 4 : ajoutez les titres et les labels

# %% [markdown]
# **Question 14** : Observez-vous des catégories très dominantes ou très rares dans House Prices ?
#
# _Votre réponse ici._

# %% [markdown]
# ### B6 - Relations entre les variables et la target
#
# On cherche maintenant quelles variables semblent liées au prix.

# %%
# Exercice 28 - Prix moyen par catégorie
# TODO 1 : calculez le prix moyen par location
# TODO 2 : affichez par exemple les 10 locations avec le prix moyen le plus élevé
# TODO 3 : calculez le prix moyen par Furnishing
# TODO 4 : calculez le prix moyen par Transaction

# %%
# Exercice 29 - Visualiser les relations avec le prix
# TODO 1 : tracez un diagramme en barres du prix moyen par Furnishing
# TODO 2 : tracez un diagramme en barres du prix moyen par Transaction
# TODO 3 : si vous le souhaitez, tracez aussi les 10 locations avec le prix moyen le plus élevé

# %% [markdown]
# **Question 15** : Quelles variables semblent les plus intéressantes pour expliquer ou prédire le prix ?
#
# _Votre réponse ici._

# %% [markdown]
# **Commentaire House Prices** : Rédigez 4 ou 5 phrases de synthèse sur ce que vous avez compris de ce dataset.
#
# _Votre commentaire ici._

# %% [markdown]
# ---
# ## Partie C - Premières conclusions sur les features
#
# Vous allez maintenant proposer une première sélection de variables pour chaque dataset.

# %%
# Exercice 30 - Première sélection de features
# TODO 1 : créez une liste Python nommée features_titanic
# avec quelques colonnes pertinentes pour prédire Survived

# TODO 2 : créez une liste Python nommée features_house
# avec quelques colonnes pertinentes pour prédire Price (in rupees)

# TODO 3 : affichez les deux listes

# %% [markdown]
# **Question 16** : Quelles colonnes supprimeriez-vous en priorité dans Titanic ? Pourquoi ?
#
# _Votre réponse ici._

# %% [markdown]
# **Question 17** : Quelles colonnes supprimeriez-vous en priorité dans House Prices ? Pourquoi ?
#
# _Votre réponse ici._

# %% [markdown]
# **Question 18** : Quelle différence faites-vous entre un problème de **classification** et un problème de **régression** ?
#
# _Votre réponse ici._

# %% [markdown]
# ---
# ## Partie D - Synthèse finale

# %% [markdown]
# **1. Quelle est la target de Titanic ?**
#
# _Votre réponse ici._

# %% [markdown]
# **2. Quelle est la target de House Prices ?**
#
# _Votre réponse ici._

# %% [markdown]
# **3. Titanic présente-t-il un déséquilibre de classes ?**
#
# _Votre réponse ici._

# %% [markdown]
# **4. House Prices présente-t-il des déséquilibres intéressants dans certaines catégories ?**
#
# _Votre réponse ici._

# %% [markdown]
# **5. Quelles sont les principales features de Titanic ?**
#
# _Votre réponse ici._

# %% [markdown]
# **6. Quelles sont les principales features de House Prices ?**
#
# _Votre réponse ici._

# %% [markdown]
# **7. Quelles difficultés importantes avez-vous repérées dans les deux datasets ?**
#
# _Votre réponse ici._

# %% [markdown]
# **8. Quelles étapes de préparation faudrait-il faire avant d'entraîner un modèle ?**
#
# _Votre réponse ici._

# %% [markdown]
# ## Fin du TP
#
# Si vous avez terminé :
#
# - relisez vos réponses ;
# - vérifiez que les cellules importantes ont bien été exécutées ;
# - assurez-vous que vos commentaires sont rédigés en français clair ;
# - notez les variables qui vous paraissent les plus prometteuses pour la suite du module.
